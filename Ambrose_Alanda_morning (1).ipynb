# %%
#By Ambrose Alanda
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("UceResultsBySchool2011-2016.csv")
df
# Out:
#        YEAR      DISTRICT                                              SCHOOL  \
# 0      2011         WAKISO                                 GAYAZA HIGH SCHOOL
# 1      2011         MUKONO                                 NAMILYANGO COLLEGE
# 2      2011         MUKONO                             MT.ST.MARY'S,NAMAGUNGA
# 3      2011         WAKISO                        UGANDA MARTYRS SS,NAMUGONGO
# 4      2011  BUSHENYI MAIN                                    KITABI SEMINARY
# ...     ...            ...                                                ...
# 17634  2016          ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016          ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016          ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016          ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016          ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
# ...

# %%
#Get your objectives clear
#dataset before cleaning
df.head(20)
# Out:
#     YEAR      DISTRICT                                   SCHOOL  \
# 0   2011         WAKISO                      GAYAZA HIGH SCHOOL
# 1   2011         MUKONO                      NAMILYANGO COLLEGE
# 2   2011         MUKONO                  MT.ST.MARY'S,NAMAGUNGA
# 3   2011         WAKISO             UGANDA MARTYRS SS,NAMUGONGO
# 4   2011  BUSHENYI MAIN                         KITABI SEMINARY
# 5   2011    MASAKA MAIN               ST.HENRY'S COLLEGE,KITOVU
# 6   2011         WAKISO                     KING'S COLLEGE,BUDO
# 7   2011        KIBAALE              NOTRE DAME ACADEMY,BUSEESA
# 8   2011        KAMPALA               ST.JOSEPH'S GIRLS,NSAMBYA
# 9   2011         WAKISO      ST.MARY'S SECONDARY SCHOOL,KITENDE
# 10  2011        MBARARA                            NTARE SCHOOL
# 11  2011         WAKISO                ST.MARY'S COLLEGE,KISUBI
# 12  2011        KALUNGU                 BUKALASA MINOR SEMINARY
# 13  2011        MBARARA                    MARYHILL HIGH SCHOOL
# ...

# %%
#Check the shape | to determine the number of the rows and columns 
#Handled by*****************
df.shape
# Out:
# (17639, 48)

# %%
#Preparation and Preprocessing or Data cleaning
df.columns
# Out:
# Index(['YEAR', 'DISTRICT ', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1 ',
#        'FEMALE % DIV1 ', 'FEMALE TOTAL DIV2 ', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X ',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1 ', 'MALE % DIV1 ',
#        'MALE TOTAL DIV2 ', 'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3',
#        'MALE TOTAL DIV4', 'MALE % DIV4 ', 'MALE TOTAL DIV7 ', 'MALE % DIV7',
#        'MALE TOTAL DIV9 ', 'MALE % DIV9', 'MALE TOTAL X ', 'MALE % X'],
#       dtype='object')

# %%
#remove the white Spaces

# %%
#Replace columns with underscores
df.columns = df.columns.str.replace(" ", "_")
df.columns
# Out:
# Index(['YEAR', 'DISTRICT_', 'SCHOOL', 'TOTAL_CANDIDATES', 'TOTAL_DIV_1',
#        '%_DIV_1', 'TOTAL_DIV_2', '%_DIV_2', 'TOTAL_DIV_3', '%_DIV_3',
#        'TOTAL_DIV_4', '%_DIV_4', 'TOTAL_DIV_7', '%_DIV_7', 'TOTAL_DIV_9',
#        '%_DIV_9', 'TOTAL_X', '%_X', 'FEMALE_CANDIDATES', 'FEMALE_TOTAL_DIV1_',
#        'FEMALE_%_DIV1_', 'FEMALE_TOTAL_DIV2_', 'FEMALE_%_DIV2',
#        'FEMALE_TOTAL_DIV3', 'FEMALE_%_DIV3', 'FEMALE_TOTAL_DIV4',
#        'FEMALE_%_DIV4', 'FEMALE_TOTAL_DIV7', 'FEMALE_%_DIV7',
#        'FEMALE_TOTAL_DIV9', 'FEMALE_%_DIV9', 'FEMALE_TOTAL_X', 'FEMALE_%_X_',
#        'MALE_CANDIDATES', 'MALE_TOTAL_DIV1_', 'MALE_%_DIV1_',
#        'MALE_TOTAL_DIV2_', 'MALE_%_DIV2', 'MALE_TOTAL_DIV3', 'MALE_%_DIV3',
#        'MALE_TOTAL_DIV4', 'MALE_%_DIV4_', 'MALE_TOTAL_DIV7_', 'MALE_%_DIV7',
#        'MALE_TOTAL_DIV9_', 'MALE_%_DIV9', 'MALE_TOTAL_X_', 'MALE_%_X'],
#       dtype='object')

# %%
#Check for Duplicates

# %%
#zcheck for the Number of rows that are null
null_rows = df[df.isna().any(axis=1)]
before_computation = len(null_rows)

print(before_computation)
# Out:
# 14511

# %%
#Remove rows without school names
df.dropna(thresh=None, subset=['SCHOOL'], inplace=True)

# %%
#Statistics for Data Science
#Descriptive statistics, measure central tendency (Mean, median, mode, ) measure dispersion (standard)
#probability
#Inferential statistics (make predictions, identify variables and hypothesis)
#Modeling
#ML
#Regression, classification, cluster, anomaly detection
#Web Scraping using Beautiful Soup and Selenium 

#250722359866

#Python data collection
#Use method corr() calculates correlation coefficients between all columns in dataframe. 
#Strong Positive correlation 1 Strong Negative Correlation -1
#Perfect correlation 1  Pqerfect Negative Correlation 
#Good correlation : when above 0.5
#Bad correlation : when less than 0.5 can be

# %%
#Example
df = pd.DataFrame({
    'x': [1,2,3,4,5],
    'y': [6,7,8,9,10],
    'z': [11,12,13,14,15]
})

correlation = df.corr()
print(correlation)
# Out:
#      x    y    z
# x  1.0  1.0  1.0
# y  1.0  1.0  1.0
# z  1.0  1.0  1.0
