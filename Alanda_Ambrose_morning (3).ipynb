# %%
# #Python for data science

# """The  Summary
# 1.NumPy, Numerical Python helps yu with arrays effectively
# 2.Pandas, 



# Data Visualisation
# Plotting - use the library called matplotlib or seabon - create - line , scatter, bar, histogram and heatmap

# ket concepts in data science
# 1. data (text, images, videos) or semi structured data( JSON and XML)
# 2.Data mining
# 3. Machine learning
# 4. statistical Analysis
# 5. Data visualisation
# 6. Big Data
# 7. Predictive Analysis


# Understanding data science workflow
# 1.Problem definition
# 2.Data Acquisition data.gov, kaggle, databases, APIs, External datasets

# Ensure data quality, data validation, cleaning and processing
# EDA Data Exploratory Analysis

# Data Preparation and Perprocessing
# 1. Missing data
# 2. Wrong format
# 3. Null Values
# 4. Duplicates


# # Import Libraries
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# #Control Display of seaborn data
# pd.options.display.max_columns=50
# sns.set(style="darkgrid", rc={"axes.facecolor":"#CAF1DE"})




# Understanding of the data
# 1.shape of the data
# df.shape

# 2.Checking column names
# df.columns

# 3.Checking for info
# df.info()

# 4.Checking for null values
# df.isnull().sum().sort_values(ascending=False)
# 3



# 6.Checking null values in figure
# import missingno as msno
# msno.bar(df, color = "gray", fontsize=24)

# 7.Checking for duplicates
# df.duplicated().sum()


# 8.Describe() statistical details about your data
# df.describe().T

# #Check for the unique values in columns
# for i in df.columns
#      print(i,"------",df[i].unique())


# https://www.youtube.com/@Jeff_Geoff_Masterclass
# """

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Control Display of seaborn data
pd.options.display.max_columns=50
sns.set(style="darkgrid", rc={"axes.facecolor":"#CAF1DE"})

# %%
df = pd.read_csv("bse_dataset.csv")
df
# Out:
#               Timestamp What is your gender?   Age What is your emotion?  \
# 0   05/07/2023 09:38:39                 Male  21.0               Content
# 1   05/07/2023 09:38:57        Marabou stock  45.0                 Weird
# 2   05/07/2023 09:39:09              Female   20.0                 Happy
# 3   05/07/2023 09:39:12                 Male  21.0                 Happy
# 4   05/07/2023 09:39:14               Female  21.0                 Happy
# ..                  ...                  ...   ...                   ...
# 92  05/07/2023 09:53:56              Female   68.0                   Sad
# 93  05/07/2023 09:54:13                 Male  29.0               Hopeful
# 94  05/07/2023 09:54:28                 Male  22.0      Fighting poverty
# 95  05/07/2023 09:54:36                 Male  23.0          good and bad
# 96  05/07/2023 09:54:52                 male  30.0                hunger
#
#    Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# ...

# %%
# Understanding of the data
# 1.shape of the data
df.shape
# Out:
# (97, 11)

# %%
# 2.Checking column names
df.columns
# Out:
# Index(['Timestamp', 'What is your gender?', 'Age', 'What is your emotion?',
#        'Year of birth', 'What is your CGPA?',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? '],
#       dtype='object')

# %%
# 3.Checking for the information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           97 non-null     object
#  1   What is your gender?                                97 non-null     object
#  2   Age                                                 96 non-null     float64
#  3   What is your emotion?                               96 non-null     object
#  4   Year of birth                                       97 non-null     object
#  5   What is your CGPA?                                  97 non-null     object
#  6   Do you have a Girl Friend or BOY Friend             97 non-null     object
#  7   Do you have Depression?                             97 non-null     object
# ...

# %%
# 4.Checking for null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Age                                                   1
# What is your emotion?                                 1
# Timestamp                                             0
# What is your gender?                                  0
# Year of birth                                         0
# What is your CGPA?                                    0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Anxiety?                                  0
# Do you have Panic attack?                             0
# Did you have seek any specialist for a treatment?     0
# dtype: int64

# %%
# 5.Checking null values in percentages
for i in df.columns:
    if df[i].isnull().any():
        print(i,"--------", df[i].isnull().sum()*100/df.shape[0],"%")
# Out:
# Age -------- 1.0309278350515463 %
# What is your emotion? -------- 1.0309278350515463 %

# %%
# 7.Checking for duplicates
df.duplicated().sum()


# 8.Describe() statistical details about your data
df.describe().T
# Out:
#      count       mean       std   min   25%   50%    75%   max
# Age   96.0  22.947917  6.303499  19.0  21.0  21.0  22.25  68.0

# %%
df.describe(include="object").T
# Out:
#                                                    count unique  \
# Timestamp                                             97     90
# What is your gender?                                  97     10
# What is your emotion?                                 96     50
# Year of birth                                         97     18
# What is your CGPA?                                    97     61
# Do you have a Girl Friend or BOY Friend               97     14
# Do you have Depression?                               97     13
# Do you have Anxiety?                                  97     18
# Do you have Panic attack?                             97     13
# Did you have seek any specialist for a treatment?     97      9
#
#                                                                     top freq
# Timestamp                                           05/07/2023 09:40:42    2
# What is your gender?                                               Male   41
# ...

# %%
# 6.Checking null values in figure
# import missingno as msno
# msno.bar(df, color = "gray", fontsize=24)

# %%
#Check for the unique values in columns
for i in df.columns:
    print(i,"------",df[i].unique())
# Out:
# Timestamp ------ ['05/07/2023 09:38:39' '05/07/2023 09:38:57' '05/07/2023 09:39:09'
#  '05/07/2023 09:39:12' '05/07/2023 09:39:14' '05/07/2023 09:39:20'
#  '05/07/2023 09:39:21' '05/07/2023 09:39:23' '05/07/2023 09:39:26'
#  '05/07/2023 09:39:27' '05/07/2023 09:39:28' '05/07/2023 09:39:33'
#  '05/07/2023 09:39:38' '05/07/2023 09:39:40' '05/07/2023 09:39:45'
#  '05/07/2023 09:39:46' '05/07/2023 09:39:47' '05/07/2023 09:39:49'
#  '05/07/2023 09:39:50' '05/07/2023 09:39:54' '05/07/2023 09:39:56'
#  '05/07/2023 09:40:00' '05/07/2023 09:40:01' '05/07/2023 09:40:02'
#  '05/07/2023 09:40:08' '05/07/2023 09:40:10' '05/07/2023 09:40:12'
#  '05/07/2023 09:40:13' '05/07/2023 09:40:16' '05/07/2023 09:40:25'
#  '05/07/2023 09:40:26' '05/07/2023 09:40:27' '05/07/2023 09:40:33'
#  '05/07/2023 09:40:34' '05/07/2023 09:40:40' '05/07/2023 09:40:42'
#  '05/07/2023 09:40:46' '05/07/2023 09:40:47' '05/07/2023 09:40:54'
#  '05/07/2023 09:40:59' '05/07/2023 09:41:00' '05/07/2023 09:41:01'
# ...
