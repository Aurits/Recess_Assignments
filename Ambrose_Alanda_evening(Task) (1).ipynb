# %%
import requests
import json
import pandas as pd


response = requests.get('https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow')
resp = response.json()['items']


print(type(resp))
print(pd.DataFrame(resp))
# Out:
# <class 'list'>
#                                                  tags  \
# 0                               [c#, loops, do-while]
# 1                                [google-apps-script]
# 2                      [c#, vlc, libvlc, libvlcsharp]
# 3                    [reactjs, react-native, i18next]
# 4   [java, selenium-webdriver, google-chrome-headl...
# 5               [android, scale, textview, word-wrap]
# 6          [node.js, amazon-web-services, aws-lambda]
# 7   [c++, constructor, initialization, static-memb...
# 8                            [c++, proxy, boost-asio]
# 9                                 [javascript, regex]
# 10                                        [php, html]
# 11          [python, session, python-requests, proxy]
# 12                       [c++, struct, compare, maps]
# 13  [reactjs, angular, webpack-5, micro-frontend, ...
# 14            [angular, angularjs, angular-ui-router]
# 15  [r, dplyr, replace, conditional-statements, mu...
# ...

# %%
import pandas as pd

data = {
    '2023-07-01': 'Saturday',
    '2023-07-02': 'Sunday',
    '2023-07-03': 'Monday',
    '2023-07-04': 'Tuesday',
    '2023-07-05': 'Wednesday'
}
print("My free days!!!!\n\n")
series = pd.Series(data)
print(series)
# Out:
# My free days!!!!
#
#
# 2023-07-01     Saturday
# 2023-07-02       Sunday
# 2023-07-03       Monday
# 2023-07-04      Tuesday
# 2023-07-05    Wednesday
# dtype: object

# %%
#the exercise

# %%
print("Assignment solutions")
# Out:
# Assignment solutions

# %%
# Import Libraries
import numpy as np
import pandas as pd


print("Using the work dataset")
df = pd.read_csv("Work.csv")
df
# Out:
# Using the work dataset
#      Name         city    age py-score
# 0    Emma      Kampala     23       90
# 1  Wilber        Mbale     26       75
# 2   Robin         Gulu     25     mine
# 3   Tevor  Livingstone    NaN       89
# 4    Yeko       Tororo     20       94
# 5  Miriam         Arua  Train      NaN
# 6   Jesca      Mbarara     21       84

# %%
#All solutions

# Question 1: Print the first few rows of the dataset using the `head()` method.
print("Question 1: Print the first few rows of the dataset")
print(df.head())

# Question 2: Print the last few rows of the dataset using the `tail()` method.
print("\n\nQuestion 2: Print the last few rows of the dataset")
print(df.tail())

# Question 3: Display information about the dataset using the `info()` method.
print("\n\nQuestion 3: Display information about the dataset")
print(df.info())

# Question 4: Remove rows with missing values (NaN) using the `dropna()` method.
print("\n\nQuestion 4: Remove rows with missing values")
df_cleaned = df.dropna()
print(df_cleaned)

# Question 5: Fill in missing values (NaN) with a specific value using the `fillna()` method.
print("\n\nQuestion 5: Fill in missing values")
df_filled = df.fillna('N/A')
print(df_filled)

# Question 6: Remove rows with wrong data or specific conditions
print("\n\nQuestion 6: Remove rows with wrong data or specific conditions")
df_cleaned = df.drop(df[(df['py-score'] == 'mine') | (df['py-score'] == 'Train')].index)
print(df_cleaned)

# Question 7: Remove duplicate rows from the dataset using the `drop_duplicates()` method.
print("\n\nQuestion 7: Remove duplicate rows from the dataset")
df_cleaned = df.drop_duplicates()
print(df_cleaned)

# Question 8: Perform correlation analysis on the dataset
print("\n\nQuestion 8: Perform correlation analysis on the dataset")
correlation_matrix = df.corr(numeric_only=True)
print(correlation_matrix)
# Out:
# Question 1: Print the first few rows of the dataset
#      Name         city  age py-score
# 0    Emma      Kampala   23       90
# 1  Wilber        Mbale   26       75
# 2   Robin         Gulu   25     mine
# 3   Tevor  Livingstone  NaN       89
# 4    Yeko       Tororo   20       94
#
#
# Question 2: Print the last few rows of the dataset
#      Name         city    age py-score
# 2   Robin         Gulu     25     mine
# 3   Tevor  Livingstone    NaN       89
# 4    Yeko       Tororo     20       94
# 5  Miriam         Arua  Train      NaN
# 6   Jesca      Mbarara     21       84
#
#
# Question 3: Display information about the dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7 non-null      object
#  1   city      7 non-null      object
#  2   age       6 non-null      object
#  3   py-score  6 non-null      object
# ...

# %%
print("Using the mine dataset")
df = pd.read_csv("mine.csv")
df
# Out:
# Using the mine dataset
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#All solutions ---Mine

# Question 1: Print the first few rows of the dataset using the `head()` method.
print("Question 1: Print the first few rows of the dataset")
print(df.head())

# Question 2: Print the last few rows of the dataset using the `tail()` method.
print("\n\nQuestion 2: Print the last few rows of the dataset")
print(df.tail())

# Question 3: Display information about the dataset using the `info()` method.
print("\n\nQuestion 3: Display information about the dataset")
print(df.info())

# Question 4: Remove rows with missing values (NaN) using the `dropna()` method.
print("\n\nQuestion 4: Remove rows with missing values")
df_cleaned = df.dropna()
print(df_cleaned)

# Question 5: Fill in missing values (NaN) with a specific value using the `fillna()` method.
print("\n\nQuestion 5: Fill in missing values")
df_filled = df.fillna('N/A')
print(df_filled)

# Question 6: Remove rows with wrong data or specific conditions
print("\nQuestion 6: Remove rows with wrong data or specific conditions")
df_cleaned = df.dropna(subset=['Calories'])
print(df_cleaned)

# Question 7: Remove duplicate rows from the dataset using the `drop_duplicates()` method.
print("\n\nQuestion 7: Remove duplicate rows from the dataset")
df_cleaned = df.drop_duplicates()
print(df_cleaned)

# Question 8: Perform correlation analysis on the dataset
print("\n\nQuestion 8: Perform correlation analysis on the dataset")
correlation_matrix = df.corr(numeric_only=True)
print(correlation_matrix)
# Out:
# Question 1: Print the first few rows of the dataset
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
#
#
# Question 2: Print the last few rows of the dataset
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
#
# Question 3: Display information about the dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
# ...
